# %% [markdown]
# # V0.1 Updates
# - Enabled serialization/deserialization for the subclassed Seq2SeqPredictor model (i.e model arch, weights and conf can be saved and loaded smoothly).
# - Enabled Customized mlflow model registery in zipped keras format.
# - Enabled Customized mlflow dataset metadata registery.
# - Traced and solved all the future warnings in pandas. This will facilitate model migration to future versions with minor modifications.
# - Added a TOC.
# - Dynamic allocation of the project root path in section #1.2.
# - Migration from os.path to pathlib for better and readable path handling.

# %% [markdown]
# # **Table of contents**<a id='toc0_'></a>
# - 1. [General](#toc1_)
#   - 1.1. [Import Libraries](#toc1_1_)
#   - 1.2. [Project Pathes](#toc1_2_)
#   - 1.3. [Services and Servers](#toc1_3_)
# - 2. [Data Loader](#toc2_)
# - 3. [Exploratory Data Analysis (EDA)](#toc3_)
#   - 3.1. [Helper Classes / Functions](#toc3_1_)
#   - 3.2. [Prelimenary EDA](#toc3_2_)
#     - 3.2.1. [Dataset in table form](#toc3_2_1_)
#     - 3.2.2. [Statistical Properties and Datatypes](#toc3_2_2_)
#   - 3.3. [Missingness Analysis](#toc3_3_)
#   - 3.4. [Univariate Analaysis](#toc3_4_)
#     - 3.4.1. [Global_active_power](#toc3_4_1_)
#     - 3.4.2. [Voltage](#toc3_4_2_)
#     - 3.4.3. [Sub_metering_1 (Kitchen)](#toc3_4_3_)
#     - 3.4.4. [Sub_metering_2(laundry room)](#toc3_4_4_)
#     - 3.4.5. [Sub_metering_3(water-heater and A/C)](#toc3_4_5_)
# - 4. [Data Preprocessing](#toc4_)
#   - 4.1. [Helper Classes / Functions](#toc4_1_)
#   - 4.2. [Downsampling the time series](#toc4_2_)
#   - 4.3. [Scaling](#toc4_3_)
#   - 4.4. [feature Selection](#toc4_4_)
#   - 4.5. [Sequence Creation](#toc4_5_)
# - 5. [Modeling](#toc5_)
#   - 5.1. [Helper Classes / Functions](#toc5_1_)
#   - 5.2. [Model Architecture](#toc5_2_)
#   - 5.3. [1st Expirement](#toc5_3_)
#     - 5.3.1. [first run](#toc5_3_1_)
#     - 5.3.2. [second run](#toc5_3_2_)
#     - 5.3.3. [Third run](#toc5_3_3_)
# - 6. [Evaluation](#toc6_)
# - 7. [Deployment](#toc7_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # 1. <a id='toc1_'></a>[General](#toc0_)

# %% [markdown]
# ## 1.1. <a id='toc1_1_'></a>[Import Libraries](#toc0_)

# %% [markdown]
# Here, Important libraries are imported:

# %%
# General 
from enum import Enum
import os
import subprocess
#from itertools import chain
import pickle
import pathlib

# Data Extraction
from ucimlrepo import fetch_ucirepo 

# Datastructures
import numpy as np
import pandas as pd

# DataPreprocessing
from sklearn.model_selection import train_test_split


# Modeling 
import tensorflow as tf
from tensorflow import keras

# Expirement Tracking
import mlflow

# Model Deployment
from flask import Flask, request, jsonify

# Visualization
import matplotlib.pyplot as plt
import seaborn as sb
# Out:
# 2024-05-06 23:46:35.693115: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-06 23:46:35.726496: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 23:46:35.726529: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 23:46:35.727816: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-06 23:46:35.735051: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-06 23:46:36.333679: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## 1.2. <a id='toc1_2_'></a>[Project Pathes](#toc0_)

# %% [markdown]
# Here, the pathes for the project folder, data subfolder, etc are encapsulated in 2 Enums, one for local pathes, and the other for remote ones :

# %%
def find_project_path(repo_name):
    current_path= pathlib.Path().absolute().resolve()
    project_path = current_path.parent
    while True:   
        project_path = project_path / repo_name
        if  project_path.exists():
            break
        else:
            project_path = project_path.parent.parent
            
    return project_path

class localpath(Enum):
    project = find_project_path(repo_name= "Energy-Consumption-Prediction" )
    _data = project/'data'
    data_raw=  _data/'raw'
    data_interim =  _data/'interim'
    data_processed = _data/'processed'
    models =  project/'models'
    _reports=  project/'reports'
    figures=  _reports/'figures'

# %% [markdown]
# ## 1.3. <a id='toc1_3_'></a>[Services and Servers](#toc0_)

# %% [markdown]
# Here, a MLflow server is instantiated at http://127.0.0.1:8080:

# %%
process = subprocess.Popen(['mlflow', 'server', '--host', '127.0.0.1', '--port', '8080'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")

# %% [markdown]
# A tensorboard server is instantiated at:

# %%
# %load_ext tensorboard

# %% [markdown]
# # 2. <a id='toc2_'></a>[Data Loader](#toc0_)

# %% [markdown]
# In this section, the DataLoader calss is utilized to load data from the online HF source to the local drive. Then, it is loaded from the local drive to the RAM.
#
# - **Note**: Since the data size is very small, it is accepted that we load it directly to ram instead of designing a dynamic data pipeline (A practical scenario for loading data dynamically in parallel to training).

# %%
class DataLoader:

    def __init__(self:object,raw_path:str=None,interim_path:str=None,raw_prefix:str=None,train_prefix:str=None,test_prefix:str=None,val_prefix:str=None,split:tuple=(0.2,0.2)):
        self.raw_path= raw_path
        self.interim_path= interim_path
        self.raw_prefix=raw_prefix
        self.train_prefix= train_prefix
        self.test_prefix= test_prefix
        self.val_prefix= val_prefix
        self.split= split

        self.raw_data= None
        self.train_data= None
        self.test_data= None
        self.val_data= None

    def load_from_ucirepo(self, id:int, raw_prefix:str=None,n_attempts: int = 2):
        if raw_prefix:
            self.raw_prefix=raw_prefix
        
        for attempt in range(n_attempts):
            try:
                self.raw_data= fetch_ucirepo(id =id).data.features
            except Exception as e:
                print(f"Attempt{attempt+1} to download data failed: {e}")
            else:
                print('Data dwonloaded successfully from source!')
                break
                
        for attempt in range(n_attempts):
            try:
                csv_path=self.raw_path/ (self.raw_prefix+'.csv')
                self.raw_data.to_csv(csv_path,index=False)
            except Exception as e:
                print(f"Attempt {attempt+1} to save file failed: {e}")
            else:
                print(f'Data saved successfully to local path!:{csv_path}')
                break

        return self.raw_data
   
    def load_from_local(self,n_attempts:int=3,raw_prefix:str=None)->pd.DataFrame:
        if raw_prefix != None:
            self.raw_prefix=raw_prefix
        # load the csv file
        csv_path= self.raw_path/(self.raw_prefix+'.csv')
        self.raw_data= self.__csv_reader(csv_path,n_attempts, low_memory=False)
        # parse date
        self.raw_data['datetime'] = pd.to_datetime(self.raw_data.pop('Date')+' '+self.raw_data.pop('Time'),
                                format="%d/%m/%Y %H:%M:%S")
        self.raw_data= self.raw_data.set_index('datetime')
        # Change any non numeric value to nan, then convert all to float
        self.raw_data = self.raw_data.replace({'[^0-9.]': ''}, regex=True)
        self.raw_data = self.raw_data.replace({'': np.nan})
        self.raw_data= self.raw_data.astype(float)
        return self.raw_data

    
    def __csv_reader(self,file_path:str,n_attempts:int=3,**pd_parameters)->pd.DataFrame:
        """A private method to read the csv file into a pandas dataframe

        Args:
            file_path (str): The path of the CSV file

        Returns:
            df (pd.DataFrame): The pandas DataFrame containing the data in the given CSV file
        """
        df=None
        for attempt in range(n_attempts):
            try:
                df = pd.read_csv(filepath_or_buffer=file_path,**pd_parameters)
            except Exception as e:
                print(f"Attempt {attempt+1} failed: {e}")
            else:
                print(f'Data Loaded successfully from the local path:{file_path}')
                break
        return df
    
    def split_data(self,split=(0.2,0.2),raw_prefix:str=None):
        if raw_prefix != None:
            self.raw_prefix=raw_prefix        
        
        if type(self.raw_data)==None:
            self.raw_data= self.load_from_local(raw_prefix=self.raw_prefix)

        if split:
            self.split=split

        if self.split[1] !=0:
            val_size= self.split[1]/(1-self.split[0])
            self.train_data,self.test_data= train_test_split(self.raw_data,test_size=self.split[0] ,shuffle=False)
            self.train_data,self.val_data= train_test_split(self.train_data,test_size=val_size,shuffle=False)

            #change datatypes to float
            self.train_data.astype(float)
            self.val_data.astype(float)
            self.test_data.astype(float)

            return  self.train_data, self.val_data, self.test_data
        else:
            self.train_data,self.test_data= train_test_split(self.raw_data,test_size=self.split[0],shuffle=False)
            return  self.train_data,self.test_data

    def __repr__(self) -> str:
         return 'DataLoader'

# %%
#Initialize the DataLoader 
data_loader = DataLoader(raw_path= localpath.data_raw.value,
                       interim_path=localpath.data_interim.value)

# Download from the online source
#data_raw= data_loader.load_from_ucirepo(id=235, raw_prefix='energy_raw_data')

# load from local, and split to train/val/test'
data_raw = data_loader.load_from_local(raw_prefix='energy_raw_data')
data_train, data_val,data_test = data_loader.split_data(split=(0.2,0.2))
# Out:
# Data Loaded successfully from the local path:/mnt/d/projects/Energy-Consumption-Prediction/data/raw/energy_raw_data.csv

# %% [markdown]
# # 3. <a id='toc3_'></a>[Exploratory Data Analysis (EDA)](#toc0_)

# %% [markdown]
# In this section, review data is explored in order to understand patterns in the data. This may help us take suitable decisions while modeling.

# %% [markdown]
# ## 3.1. <a id='toc3_1_'></a>[Helper Classes / Functions](#toc0_)

# %%
def print_shape(X:pd.DataFrame):
    """Prints the shape of a pandas dataframe

    Args:
        X (pd.DataFrame):  The pandas dataframe under examination

    """    
    for name, value in globals().items():
        if value is X:
           X.name= name 

    if type(X) == pd.core.series.Series:
        print ("The",X.name ,"series"+" has",X.shape[0]," rows")  
        
    elif type(X) == pd.core.frame.DataFrame:
    
        print ("The",X.name ,"dataframe"+" has",X.shape[0]," rows and",X.shape[1] ,"columns" ) 
        
    return None

# %%
def print_df(df:pd.DataFrame,n:int=5, max_col:int=None, max_rows:int=None, random:bool=True, flatten_col:bool=False):
    """_summary_

    Args:
        df (Pandas.Dataframe) : The pandas dataframe under examination
        n (int): number of rows to print
        max_col(int): maximum number of columns to print. If None, all the columns will be printed
        max_rows(int): maximum number of rows to print. If None, all the rows will be printed
        random (Bool): If True, random n samples will be printed
        flatten_col:(Bool): If True, all the cell content will be printed

   
    """    
    #setting the maximum number of columns and rows to be printed
    pd.set_option( "display.max_columns", max_col, "display.max_rows", max_rows)
    if flatten_col:
        pd.set_option( "display.max_colwidth", None) 
    
    #Sampling an n random rows from the dataframe to be displayed
    if random: 
        row_indices = np.random.randint(0,df.shape[0],n)
    elif random == False:
        row_indices= range(0,n)
    
    #printing the dataframe
    print("\033[1m The", df.name,"dataframe:" )
    display(df.iloc[row_indices,:])

# %%
def list_missingness(df:pd.DataFrame, only_missing:bool=False, percentage:bool=True):
    """_summary_

    Args:
        df (pd.DataFrame): The pandas dataframe under examination
        only_missing (bool, optional):  If True, only columns with non zero missingness will be printed.
        percentage (bool, optional): If True, the missingness percentage will be returned instead of numbers.
    Returns:
        nan_per_col: number/percent of missing values in each column
    """      
    nan_per_col = df.isnull().sum(axis = 0).sort_values(ascending = False)
    nan_per_row = df.isnull().any(axis=1).sum()
    if only_missing:
        nan_per_col = nan_per_col.loc[nan_per_col!=0] 
    
    
    if percentage:
        nan_per_col = (nan_per_col /len(df))*100

    print(f"The total numbe of rows with missing values are: {nan_per_row} which is {nan_per_row/len(df)}% of the data.\n" )
    print(f"The missingness percentage for each variable in {'%' if percentage else'numbers'}:\n{nan_per_col}")
    
    return nan_per_col

# %%
def find_cons_nan(series):

    cons_nan = series.isnull().astype(int).groupby(series.notnull().astype(int).cumsum()).sum()
    cons_nan= cons_nan[cons_nan!=0]
    return cons_nan

# %%
def plot_cont_dist(df:pd.DataFrame ,cont_var:str):
    """Plots the distribution of a continues variable versus values of the target variable

    Args:
        df (pd.DataFrame): The pandas dataframe containing the continues variable under examination
        cont_var (str): ame of the column containing the variable under examination
    """    
    # xlim
    min = 0.7* df[cont_var].min()
    max = 1.05* df[cont_var].max()  
    
    fig, ax = plt.subplots(figsize=(10,5))

    #plotting the variable distribution
    s1 = sb.histplot(ax = ax, data = df, x = cont_var, stat = 'density' , element= 'step')
    ax.set_xlim(min,max)
    ax.legend([cont_var], loc ="upper right")    
    ax.set_title(cont_var + ' distribution', fontdict={'fontsize' : 10, 'fontweight' : 3, 'color' : 'Blue'})

# %%
def plot_ts(df:pd.DataFrame,col:str,start_datetime:pd.Timestamp,end_datetime:pd.Timestamp,title:str,save_location:str=None):
    """pltos a time series column in a pandas dataframe

    Args:
        df (pd.DataFrame): The pandas dataframe containing the time series
        col (str): The time series column
        start_datetime (pd.Timestamp): The start date for the plot
        end_datetime (pd.Timestamp): The end date for the plot
        title (str): The title to be shown ijn the plot
    """    
    # %matplotlib inline
    ax= df[start_datetime:end_datetime].plot(y=col)
    ax.set_title(title)
    if save_location !=None:    
        plt.savefig(save_location/(title+'.png'),bbox_inches='tight')

# %% [markdown]
# ## 3.2. <a id='toc3_2_'></a>[Prelimenary EDA](#toc0_)

# %% [markdown]
# ### 3.2.1. <a id='toc3_2_1_'></a>[Dataset in table form](#toc0_)

# %%
#p Printing the shapes of the dataset splits
print_shape(data_train)
print_shape(data_val)
print_shape(data_test)
# Out:
# The data_train dataframe has 1245155  rows and 7 columns
# The data_val dataframe has 415052  rows and 7 columns
# The data_test dataframe has 415052  rows and 7 columns

# %%
# printing the training dataset
print_df(df=data_train,flatten_col=True)
# Out:
#  The data_train dataframe:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2008-06-26 08:59:00                1.300                  0.104   236.69
# 2008-11-23 17:07:00                5.464                  0.060   233.63
# 2007-11-25 21:54:00                1.548                  0.000   239.92
# 2008-01-20 13:05:00                1.312                  0.202   239.36
# 2008-03-18 01:07:00                0.300                  0.086   246.60
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2008-06-26 08:59:00               5.8             0.0             1.0
# 2008-11-23 17:07:00              23.4             0.0            37.0
# 2007-11-25 21:54:00               6.8             1.0             0.0
# 2008-01-20 13:05:00               5.6             0.0             2.0
# 2008-03-18 01:07:00               1.2             0.0             0.0
#
#                      Sub_metering_3
# datetime
# 2008-06-26 08:59:00            17.0
# 2008-11-23 17:07:00             0.0
# 2007-11-25 21:54:00             0.0
# 2008-01-20 13:05:00             0.0
# 2008-03-18 01:07:00             0.0

# %% [markdown]
# ### 3.2.2. <a id='toc3_2_2_'></a>[Statistical Properties and Datatypes](#toc0_)

# %%
# description of all variables, including all datatypes
data_train.describe(include='all')
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         1.241016e+06           1.241016e+06  1.241016e+06
# mean          1.131053e+00           1.158859e-01  2.403827e+02
# std           1.124031e+00           1.086206e-01  3.389692e+00
# min           7.600000e-02           0.000000e+00  2.234900e+02
# 25%           3.000000e-01           0.000000e+00  2.383400e+02
# 50%           6.000000e-01           9.600000e-02  2.405500e+02
# 75%           1.566000e+00           1.800000e-01  2.426000e+02
# max           1.112200e+01           1.390000e+00  2.539400e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      1.241016e+06    1.241016e+06    1.241016e+06    1.241016e+06
# mean       4.800325e+00    1.203548e+00    1.439886e+00    6.129587e+00
# std        4.733252e+00    6.407848e+00    6.327597e+00    8.308327e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# 25%        1.400000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 50%        2.600000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 75%        6.600000e+00    0.000000e+00    1.000000e+00    1.700000e+01
# max        4.840000e+01    8.200000e+01    7.800000e+01    3.100000e+01

# %% [markdown]
# **Comments:** <br>
# - All The dataset variables are continuos.
# - Dataset variables have different range and possibly different distributions

# %% [markdown]
# ## 3.3. <a id='toc3_3_'></a>[Missingness Analysis](#toc0_)

# %%
# check if there are missing indices (if no freq)
pd.infer_freq(data_train.index)
# Out:
# 'min'

# %%
# print missing values report
missing_perc =list_missingness(df=data_train, only_missing=False,
                               percentage=True)
# Out:
# The total numbe of rows with missing values are: 4139 which is 0.0033240841501660434% of the data.
#
# The missingness percentage for each variable in %:
# Global_active_power      0.332408
# Global_reactive_power    0.332408
# Voltage                  0.332408
# Global_intensity         0.332408
# Sub_metering_1           0.332408
# Sub_metering_2           0.332408
# Sub_metering_3           0.332408
# dtype: float64

# %% [markdown]
# **Comments**:
# - In a timeseries, missingness may have one of two forms: 1- missing indices(dates). 2- Missing values on existing dates.
# - The dataset has no missing dates (since frequency is inferred successfully).
# - Missingness is minor, but it shall be handled so we leave no gaps in the dataset

# %% [markdown]
# ## 3.4. <a id='toc3_4_'></a>[Univariate Analaysis](#toc0_)

# %% [markdown]
# ### 3.4.1. <a id='toc3_4_1_'></a>[Global_active_power](#toc0_)

# %% [markdown]
# Day plot(in winter):

# %%
plot_ts(df=data_train,col='Global_active_power',start_datetime='2007-01-17 00:00:00',
        end_datetime='2007-01-18 00:00:00',title="Active Power in A Random Winter Day",
        save_location=localpath.figures.value)

# %% [markdown]
# Day plot(in Summer):

# %%
plot_ts(df=data_train,col='Global_active_power',start_datetime='2007-07-17 00:00:00',
        end_datetime='2007-07-18 00:00:00',title="Active Power in A Random Summer Day",
        save_location=localpath.figures.value)

# %% [markdown]
# One Week plot:

# %%
plot_ts(df=data_train,col='Global_active_power',start_datetime='2007-06-04 00:00:00',
        end_datetime='2007-06-10 00:00:00',title="Active Power in A Random Week",
        save_location=localpath.figures.value)

# %% [markdown]
# **Comments**:
# - On both summer and winter, people tend to use electricity starting from 7:00AM. This is the regular and expected behavior taking into account the basic human sleep cycle.
# - In summer, the peak usage is between 6:00AM and 9:00 AM (Bedore people leave home).
# - In Winter, he peak usage is between 9:00AM and 6:00 PM.

# %% [markdown]
# ### 3.4.2. <a id='toc3_4_2_'></a>[Voltage](#toc0_)

# %% [markdown]
# Day plot(in winter):

# %%
plot_ts(df=data_train,col='Voltage',start_datetime='2007-01-17 00:00:00',
        end_datetime='2007-01-18 00:00:00',title="Voltage in A Random Winter Day",
        save_location=localpath.figures.value)

# %% [markdown]
# Day plot(in Summer):

# %%
plot_ts(df=data_train,col='Voltage',start_datetime='2007-07-17 00:00:00',
        end_datetime='2007-07-18 00:00:00',title="Voltage in A Random Summer Day",
        save_location=localpath.figures.value)

# %% [markdown]
# One Week plot:

# %%
plot_ts(df=data_train,col='Voltage',start_datetime='2007-06-04 00:00:00',
        end_datetime='2007-06-10 00:00:00',title="Voltage in A Random Week",
        save_location=localpath.figures.value)

# %%
data_train.loc['2007-07-17 00:00:00':'2007-07-18 00:00:00','Voltage'].std()
# Out:
# 2.142921014256072

# %%
data_train.loc['2007-01-17 00:00:00':'2007-01-18 00:00:00','Voltage'].std()
# Out:
# 2.7820328320005663

# %% [markdown]
# **Comments**:
# - The Voltage is fluctating either in winter or in summer. The std is 2:3.

# %% [markdown]
# ### 3.4.3. <a id='toc3_4_3_'></a>[Sub_metering_1 (Kitchen)](#toc0_)

# %% [markdown]
# Day plot(in winter):

# %%
plot_ts(df=data_train,col='Sub_metering_1',start_datetime='2007-12-17 00:00:00',
        end_datetime='2007-12-18 00:00:00',title="Kitchen Energy in A Random Winter Day",
        save_location=localpath.figures.value)

# %% [markdown]
# Day plot(in Summer):

# %%
plot_ts(df=data_train,col='Sub_metering_1',start_datetime='2007-06-17 00:00:00',
        end_datetime='2007-06-18 00:00:00',title="Kitchen Energy in A Random Summer Day",
        save_location=localpath.figures.value)

# %% [markdown]
# One Week plot:

# %%
plot_ts(df=data_train,col='Sub_metering_1',start_datetime='2007-06-04 00:00:00',
        end_datetime='2007-06-10 00:00:00',title="Kitchen Energy in A Random Week",
        save_location=localpath.figures.value)

# %% [markdown]
# **Comments**:
# - People use the kitchen one to three times per day

# %% [markdown]
# ### 3.4.4. <a id='toc3_4_4_'></a>[Sub_metering_2(laundry room)](#toc0_)

# %% [markdown]
# Day plot(in winter):

# %%
plot_ts(df=data_train,col='Sub_metering_2',start_datetime='2008-01-17 00:00:00',
        end_datetime='2008-01-18 00:00:00',title="Laundry Energy in A Random Winter Day",
        save_location=localpath.figures.value)

# %% [markdown]
# Day plot(in Summer):

# %%
plot_ts(df=data_train,col='Sub_metering_2',start_datetime='2007-06-18 00:00:00',
        end_datetime='2007-06-19 00:00:00',title="Laundry Energy in A Random Summer Day",
        save_location=localpath.figures.value)

# %% [markdown]
# One Week plot:

# %%
plot_ts(df=data_train,col='Sub_metering_2',start_datetime='2007-06-04 00:00:00',
        end_datetime='2007-06-10 00:00:00',title="Laundry Energy in A Random Week",
        save_location=localpath.figures.value)

# %% [markdown]
# **Comments**:
# - People use the laundry room almost every hour.

# %% [markdown]
# ### 3.4.5. <a id='toc3_4_5_'></a>[Sub_metering_3(water-heater and A/C)](#toc0_)

# %% [markdown]
# Day plot(in winter):

# %%
plot_ts(df=data_train,col='Sub_metering_3',start_datetime='2007-12-17 00:00:00',
        end_datetime='2007-12-18 00:00:00',title="Heater-AC Energy in A Random Winter Day",
        save_location=localpath.figures.value)

# %% [markdown]
# Day plot(in Summer):

# %%
plot_ts(df=data_train,col='Sub_metering_3',start_datetime='2007-07-17 00:00:00',
        end_datetime='2007-07-18 00:00:00',title="Heater-AC Energy in A Random Summer Day",
        save_location=localpath.figures.value)

# %% [markdown]
# One Week plot:

# %%
plot_ts(df=data_train,col='Sub_metering_3',start_datetime='2007-06-04 00:00:00',
        end_datetime='2007-06-10 00:00:00',title="Heater-AC Energy  in A Random Week",
        save_location=localpath.figures.value)

# %% [markdown]
# **Comments**:
# - In winter, cooling/heater energy is more used by the house. Which means, people tend to use heating equipment more than cooling. Or eaither, the energy required for heating is higher.

# %% [markdown]
# # 4. <a id='toc4_'></a>[Data Preprocessing](#toc0_)

# %% [markdown]
# ## 4.1. <a id='toc4_1_'></a>[Helper Classes / Functions](#toc0_)

# %%
def split_series(data, window, steps):
    """splits the timeseries dataframe to a seequence of inputs/outputs

    Args:
        data (_type_): the dataframe containing timeseries variables
        window (_type_): The window to consider for prediction(past values)
        steps (_type_): The steps for predicition(future values)

    Returns:
        _type_: _description_
    """
    data= data.to_numpy()
    x, y = list(), list()
    for window_start in range(len(data)):
        past_end = window_start + window
        future_end = past_end + steps
        if future_end > len(data):
            break
        # slicing the data array to get past and future values
        past= data[window_start:past_end, :]
        x.append(past)
        future= data[past_end:future_end, :]
        y.append(future)

    # Converting to np ndarray
    x = np.array(x).astype('float32')
    y= np.array(y).astype('float32')
    return x,y

# %% [markdown]
# ## 4.2. <a id='toc4_2_'></a>[Downsampling the time series](#toc0_)

# %%
#Downsampling of Data from minutes to Days
#There are more than 2 lakh observations recorded. Let’s make the data simpler by downsampling them from the frequency of minutes to days.

data_train = data_train.resample('D').sum()
data_test = data_test.resample('D').sum()
data_val = data_val.resample('D').sum()

# %% [markdown]
# **Comments**:
# - For prediction, day-based prediction will help the company understand energy usage more.
# - Down sampling will help get red of missing values. This is not the best approach, missingness should have been analyzed and imputed in a more professional way.

# %% [markdown]
# ## 4.3. <a id='toc4_3_'></a>[Scaling](#toc0_)

# %%
from sklearn.preprocessing  import MinMaxScaler
# Definition of the scaler
Scaler = MinMaxScaler(feature_range=(0, 1))
Scaler.set_output(transform = 'pandas')

#fitting the scaler on variables of the training dataset
Scaler.fit(data_train.astype(np.float64))

data_train = Scaler.transform(data_train.astype(np.float64));
data_val = Scaler.transform(data_val.astype(np.float64));
data_test= Scaler.transform(data_test.astype(np.float64));

# %%
with open(localpath.models.value/'scaler.pickle', 'wb') as handle:
    pickle.dump(Scaler, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# - It's better to include all the preprocessing steps in the model architecture it self. But this will require much work to ensure portability

# %% [markdown]
# ## 4.4. <a id='toc4_4_'></a>[feature Selection](#toc0_)

# %% [markdown]
# - We will rely on Deep networks ability to extract features.
# - Hint: oen of the Global_intensity or voltage may be ignored as they shall be correlated with the power feature. This intuition comes from the physical understanding of the problem. After building the baseline model, this step may be examined for performance enhancement.

# %% [markdown]
# ## 4.5. <a id='toc4_5_'></a>[Sequence Creation](#toc0_)

# %%
window=3
steps=7
fratures=data_train.shape[1]

x_train,y_train=split_series(data_train,window,steps)
x_val,y_val=split_series(data_val,window,steps)
x_test,y_test=split_series(data_test,window,steps)

# %%
with open(localpath.data_processed.value/'x_train.pickle', 'wb') as handle:
    pickle.dump(x_train, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(localpath.data_processed.value/'y_train.pickle', 'wb') as handle:
    pickle.dump(y_train, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(localpath.data_processed.value/'x_val.pickle', 'wb') as handle:
    pickle.dump(x_val   , handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(localpath.data_processed.value/'y_val.pickle', 'wb') as handle:
    pickle.dump(y_val, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(localpath.data_processed.value/'x_test.pickle', 'wb') as handle:
    pickle.dump(x_test, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(localpath.data_processed.value/'y_test.pickle', 'wb') as handle:
    pickle.dump(y_test, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # 5. <a id='toc5_'></a>[Modeling](#toc0_)

# %% [markdown]
# ## 5.1. <a id='toc5_1_'></a>[Helper Classes / Functions](#toc0_)

# %%
class MlflowCallback(tf.keras.callbacks.Callback):
    """A callback to log keras metrics in the mlflow server"""
    def on_epoch_end(self, epoch, logs=None):
        mlflow.log_metric("loss", logs['loss'], step=epoch)
        mlflow.log_metric("accuracy", logs['accuracy'], step=epoch)
        if 'val_loss' in logs:
            mlflow.log_metric("val_loss", logs['val_loss'], step=epoch)
        if 'val_accuracy' in logs:
            mlflow.log_metric("val_accuracy", logs['val_accuracy'], step=epoch)

# %%
class LossPlotCallback(keras.callbacks.Callback):
    def on_train_begin(self,logs):
        # %matplotlib qt
        self.epoch = 0
        self.losses = []
        self.val_losses = []
        self.accuracies = []
        self.val_accuracies = []
        self.fig, self.axs = plt.subplots(1, 2, figsize=(12, 8))
    def on_epoch_end(self, epoch, logs=None):
            self.epoch = epoch
            self.losses.append(logs.get('loss'))
            self.val_losses.append(logs.get('val_loss'))
            self.accuracies.append(logs.get('accuracy'))
            self.val_accuracies.append(logs.get('val_accuracy'))
            self.plot_loss_acc()


    def on_train_end(self,logs):
        # %matplotlib inline
        self.plot_loss_acc()
    def plot_loss_acc(self):
        self.axs[0].cla()
        self.axs[0].plot(range(self.epoch+1),self.losses,
                        linestyle = '-',color='green',
                        label = 'Training Loss' )
        self.axs[0].plot(range(self.epoch+1),self.val_losses,
                        linestyle = '--',color='blue',
                        label = 'Validation Loss' )          
        self.axs[0].set_title('Loss Plot')
        self.axs[0].set_xlabel('Epoch')
        self.axs[0].set_ylabel('Loss')
        self.axs[0].legend()

        self.axs[1].cla()
        self.axs[1].plot(range(self.epoch+1), self.accuracies,
                        linestyle = '-',color='green',
                        label = 'Training Accuracy' )
        self.axs[1].plot(range(self.epoch+1), self.val_accuracies,
                        linestyle = '--',color='blue',
                        label = 'Validation Accuracy' )          
        self.axs[1].set_title('Accuracy Plot')
        self.axs[1].set_xlabel('Epoch')
        self.axs[1].set_ylabel('Accuracy')
        self.axs[1].legend()

        self.fig.canvas.draw()
        plt.show(block = False)
        plt.pause(0.001)

# %% [markdown]
# ## 5.2. <a id='toc5_2_'></a>[Model Architecture](#toc0_)

# %%
@keras.saving.register_keras_serializable()
class LSTMEncoder(keras.layers.Layer):
    """Subclasses a Keras layer class for the LSTM-based Encoder to encode time-series features
    
        Attributes:
            num_layers (int): number of LSTM layers
            num_units (list): A list containing the number of units per each layer respectively.
    """
    def __init__(self,num_layers:int,num_units:list,**kwargs):

        self._model_name = 'LSTMEncoder'
        kwargs.update({'name':self._model_name})
        super().__init__(**kwargs)

        self.num_units=num_units
        self.num_layers=num_layers
        
        # Define a container the proper encoder layers
        self._encoder_layers=[]
        for layer in range(self.num_layers-1):
            self._encoder_layers.append(keras.layers.LSTM(self.num_units[layer], return_sequences = True, return_state=True,dropout=0.5))
        self._encoder_layers.append(keras.layers.LSTM(self.num_units[-1], return_state=True))

   
    # def summary(self):
    #     """A custom summary that acts similar to the original summary method.
    #     This method is overriden to avoid the error (model.summary() can't print output shape while using subclass model) 
    #     """
    #     x = keras.Input(shape=, dtype=tf.float64,name='Input(in summary fun)')
    #     model = keras.models.Model(inputs=[x],outputs=self.call(x), name = self._model_name)
    #     return model.summary()
    
    
    def call(self,inputs):
        layers_state_h=[]
        layers_state_c=[]
        encoder_outputs= inputs
        for layer in self._encoder_layers:
            encoder_outputs, state_h, state_c =layer(encoder_outputs)
            layers_state_h.append(state_h)
            layers_state_c.append(state_c)
        return (encoder_outputs, layers_state_h, layers_state_c)
    
    def get_config(self):
        base_config = super().get_config()
        config={}
        config.update({"num_units":self.num_units})
        config.update({"num_layers":self.num_layers})
        return{**base_config,**config}

# %%
@keras.saving.register_keras_serializable()
class LSTMDecoder(keras.layers.Layer):
    """Subclasses a Keras layer class for the LSTM-based Decoder to predict time-series features
    
        Attributes:
            num_layers (int): number of LSTM layers
            num_units (list): A list containing the number of units per each layer respectively.
            steps (int): number of predicted future steps
            num_features (int): the number of features in each step
    """
    def __init__(self,num_layers:int,num_units:list,steps:int,num_features:int,**kwargs):
        """_summary_

        Args:
            num_layers (int): number of LSTM layers
            num_units (list): A list containing the number of units per each layer respectively.
            steps (int): number of predicted future steps
            num_features (int): the number of features in each step
        """        
        self._model_name = 'LSTMDecoder'
        kwargs.update({'name':self._model_name})
        super().__init__(**kwargs)
        self.num_units=num_units
        self.num_layers=num_layers
        self.steps=steps
        self.num_features=num_features
        # Define a container the proper encoder layers
        self._decoder_layers=[]
        # repeat the encoder output for each step
        self._decoder_layers.append(keras.layers.RepeatVector(self.steps))
        for layer in range(self.num_layers):
            self._decoder_layers.append(keras.layers.LSTM(self.num_units[layer], return_sequences = True, return_state=True))
        self._decoder_layers.append(keras.layers.TimeDistributed(tf.keras.layers.Dense(self.num_features)))
    
    # def summary(self):
    #     """A custom summary that acts similar to the original summary method.
    #     This method is overriden to avoid the error (model.summary() can't print output shape while using subclass model) 
    #     """
    #     x = keras.Input(shape=(100,100), dtype=tf.float64,name='Input(in summary fun)')
    #     model = keras.models.Model(inputs=[x],outputs=self.call(x), name = self._model_name)
    #     return model.summary()
  
    def call(self,inputs):
        # invoke the repeat vector layer
        decoder_outputs= self._decoder_layers[0](inputs[0])
        #invoke LSTM layers
        num_layers=len(self._decoder_layers)
        for i in range(1,num_layers-1):
            decoder_outputs, _, _ =self._decoder_layers[i](decoder_outputs,initial_state=(inputs[1][i-1],inputs[2][i-1]))   # i-1 because decoder has repeat vector while encoder doesn't
        # invoke the TimeDistributed layer
        output= self._decoder_layers[-1](decoder_outputs)
        
        return output
    
    def get_config(self):
        base_config = super().get_config()
        config={}
        config.update({"num_units":self.num_units})
        config.update({"num_layers":self.num_layers})
        config.update({"steps":self.steps})
        config.update({"num_features":self.num_features})

        return{**base_config,**config}

# %%
@keras.saving.register_keras_serializable()
class Seq2SeqPredictor(keras.Model):
    """Subclasses a Keras layer model to wrap the encoder and decoder in one entity.

        Attributes:
            Encoder (keras.layers.Layer): a keras layer encabsulating the encoder
            Decoder (keras.layers.Layer): a keras layer encabsulating the decoder
            num_layers (int): number of LSTM layers
            num_units (list): A list containing the number of units per each layer respectively.
            steps (int): number of predicted future steps
            num_features (int): the number of features in each step
    """

    def __init__(self,Encoder:keras.layers.Layer,Decoder:keras.layers.Layer,steps,num_features,num_layers,num_units):
        """_summary_

        Args:
            Encoder (keras.layers.Layer): _description_
            Decoder (keras.layers.Layer): _description_
            num_Dense (int): _description_
            num_neurons (list): _description_
            dropout (list): _description_
            activations (list): _description_
        """        
        self.model_name = 'Seq2SeqPredictor'
        super().__init__(name = self.model_name)
        
        self.steps = steps
        self.num_features =num_features 
        self.num_layers = num_layers
        self.num_units = num_units

        self.Encoder = Encoder(num_layers,num_units)
        self.Decoder = Decoder(num_layers,num_units,steps,num_features)
    
    def summary(self):
        """A custom summary that acts similar to the original summary method.
        This method is overriden to avoid the error (model.summary() can't print output shape while using subclass model) 
        """
        x = keras.Input(shape=(3,self.num_features), dtype=tf.float64,name='Input(in summary fun)')
        model = keras.models.Model(inputs=[x],outputs=self.call(x), name = self.model_name)
        return model.summary()
    
    def call(self, inputs):
        x = inputs
        x = self.Encoder(x)
        x = self.Decoder(x)
        return x

    def get_config(self):
        base_config = super().get_config()
        config={}
        config.update({"num_units":self.num_units})
        config.update({"num_layers":self.num_layers})
        config.update({"steps":self.steps})
        config.update({"num_features":self.num_features})
        config.update({"Encoder":keras.saving.serialize_keras_object(self.Encoder)})
        config.update({"Decoder":keras.saving.serialize_keras_object(self.Decoder)})
        return{**base_config,**config}
    
    @classmethod
    def from_config(cls, config):
        encoder_config = config.pop("Encoder")
        decoder_config = config.pop("Decoder")
        Encoder = keras.saving.deserialize_keras_object(encoder_config)
        Decoder = keras.saving.deserialize_keras_object(decoder_config)
        return cls(type(Encoder),type(Decoder),**config) 

   
    def train_model(self, compile_kwargs:dict, fit_kwargs :dict, expirement_name:str=None, run_name:str=None):
        """trains a model while keeping track of expirement and model registery.

        Args:
            compile_kwargs (dict): Keyword Arguments for keras_model.compile()
            fit_kwargs (dict): Keyword Arguments for keras_model.fit()
            expirement_name (str, optional): The expirement name for the mlflow server. Defaults to None.
            run_name (str, optional): The run name for the mlflow server. Defaults to None.

        Returns:
            _type_: _description_
        """
        
        # If expirement or run names are not given, set to default
        if expirement_name:
            mlflow.set_experiment(expirement_name)
        else:
            mlflow.set_experiment()
        
        if run_name:
            run_name = run_name
        else:
            run_name = ""
        
        # fit the model while tracking model parameters and metrics
        with mlflow.start_run(run_name = run_name) as run:
            #compile the model
            self.compile(**compile_kwargs)
            
            # log the used training and validation dataset
            training_data = mlflow.data.from_numpy(fit_kwargs['x'], targets=fit_kwargs['y'] )
            validation_data = mlflow.data.from_numpy(fit_kwargs['validation_data'][0], targets=fit_kwargs['validation_data'][1])
            mlflow.log_input(training_data, context="Training")
            mlflow.log_input(validation_data, context="Validation")
            
            # log model parameters (either given or the defaults)
            mlflow.log_param("epochs", fit_kwargs['epochs'])
            mlflow.log_param("batch_size", fit_kwargs['batch_size'])
            mlflow.log_param("optimizer_name", self.optimizer.name)
            mlflow.log_param("optimizer_learning_rate", self.optimizer.learning_rate.numpy())
            mlflow.log_param("optimizer_beta_1", self.optimizer.beta_1)
            mlflow.log_param("optimizer_beta_2", self.optimizer.beta_2)
            mlflow.log_param("optimizer_epsilon", self.optimizer.epsilon)
            mlflow.log_param("loss_name", self.loss.name)
            
            # fit method callbacks
            mlflow_callback = MlflowCallback()         # to log in mlfow server
            plot_callback = LossPlotCallback()         # to plot the learning curves dynamically
            fit_kwargs['callbacks'] = [mlflow_callback,plot_callback]
            
            # fitting the model
            history = self.fit(**fit_kwargs)

            # Evaluate the model
            loss, accuracy = self.evaluate(fit_kwargs['x'],fit_kwargs['y'])
            mlflow.log_metric("loss", loss)
            mlflow.log_metric("accuracy", accuracy)

            #log the validation metrics
            if 'validation_data' in fit_kwargs:
                validation_data = fit_kwargs['validation_data']
                val_loss, val_accuracy = self.evaluate(validation_data[0], validation_data[1])
                mlflow.log_metric("val_loss", val_loss)
                mlflow.log_metric("val_accuracy", val_accuracy)
                
            # log the model
            models_folder_path= pathlib.Path().absolute().resolve()/'mlruns/models'
            model_path= models_folder_path/(run_name+'_model.keras')
            self.save(model_path)
            mlflow.log_artifact(model_path) 
    
        mlflow.end_run()
        return history

# %% [markdown]
# ## 5.3. <a id='toc5_3_'></a>[1st Expirement](#toc0_)

# %% [markdown]
# ### 5.3.1. <a id='toc5_3_1_'></a>[first run](#toc0_)

# %%
model= Seq2SeqPredictor(Encoder=LSTMEncoder,Decoder=LSTMDecoder,steps=steps,
                        num_features=fratures,num_layers=1,num_units=[100])

compile_kwargs = { 'loss': keras.losses.MeanAbsoluteError () ,
                    'optimizer':keras.optimizers.Adam(learning_rate=0.001),
                    'metrics':['accuracy']}
                    
fit_kwargs = {'x': x_train, 'y' :y_train , 'validation_data' : (x_val,y_val),
               'epochs':100, 'batch_size' : 12,'shuffle':True}
model.train_model(compile_kwargs, fit_kwargs,expirement_name= 'Seq2seq-LSTM',run_name= '1layers-100units')
# Out:
# 2024-05-06 23:46:59.526465: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:46:59.682679: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:46:59.682736: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:46:59.684950: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:46:59.684994: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:46:59.685009: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:47:01.237027: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:47:01.237106: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:47:01.237113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-06 23:47:01.237144: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 23:47:01.237212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3446 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/100
# 2024-05-06 23:47:05.160043: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-06 23:47:08.774127: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-05-06 23:47:09.024616: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fdc44080eb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-06 23:47:09.024647: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 6GB Laptop GPU, Compute Capability 8.6
# 2024-05-06 23:47:09.031323: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715028429.092585  139112 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 72/72 [==============================] - 6s 21ms/step - loss: 0.1339 - accuracy: 0.9052 - val_loss: 0.0906 - val_accuracy: 0.9607
# Epoch 2/100
# 72/72 [==============================] - 1s 14ms/step - loss: 0.0929 - accuracy: 0.9933 - val_loss: 0.0888 - val_accuracy: 0.9607
# Epoch 3/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0907 - accuracy: 0.9933 - val_loss: 0.0842 - val_accuracy: 0.9607
# Epoch 4/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0897 - accuracy: 0.9933 - val_loss: 0.0845 - val_accuracy: 0.9607
# Epoch 5/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0897 - accuracy: 0.9933 - val_loss: 0.0853 - val_accuracy: 0.9607
# Epoch 6/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0891 - accuracy: 0.9933 - val_loss: 0.0866 - val_accuracy: 0.9607
# Epoch 7/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0895 - accuracy: 0.9933 - val_loss: 0.0856 - val_accuracy: 0.9607
# Epoch 8/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0899 - accuracy: 0.9933 - val_loss: 0.0909 - val_accuracy: 0.9607
# Epoch 9/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0882 - accuracy: 0.9933 - val_loss: 0.0817 - val_accuracy: 0.9607
# Epoch 10/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0891 - accuracy: 0.9933 - val_loss: 0.0845 - val_accuracy: 0.9607
# Epoch 11/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0885 - accuracy: 0.9933 - val_loss: 0.0864 - val_accuracy: 0.9607
# Epoch 12/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0885 - accuracy: 0.9933 - val_loss: 0.0834 - val_accuracy: 0.9607
# Epoch 13/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0880 - accuracy: 0.9933 - val_loss: 0.0895 - val_accuracy: 0.9607
# Epoch 14/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0880 - accuracy: 0.9933 - val_loss: 0.0822 - val_accuracy: 0.9607
# Epoch 15/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0875 - accuracy: 0.9933 - val_loss: 0.0813 - val_accuracy: 0.9607
# Epoch 16/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0879 - accuracy: 0.9933 - val_loss: 0.0825 - val_accuracy: 0.9607
# Epoch 17/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0872 - accuracy: 0.9933 - val_loss: 0.0823 - val_accuracy: 0.9607
# Epoch 18/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0875 - accuracy: 0.9933 - val_loss: 0.0833 - val_accuracy: 0.9607
# Epoch 19/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0872 - accuracy: 0.9933 - val_loss: 0.0810 - val_accuracy: 0.9607
# Epoch 20/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0868 - accuracy: 0.9933 - val_loss: 0.0824 - val_accuracy: 0.9607
# Epoch 21/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0876 - accuracy: 0.9933 - val_loss: 0.0829 - val_accuracy: 0.9607
# Epoch 22/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0871 - accuracy: 0.9933 - val_loss: 0.0850 - val_accuracy: 0.9607
# Epoch 23/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0870 - accuracy: 0.9933 - val_loss: 0.0824 - val_accuracy: 0.9607
# Epoch 24/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0870 - accuracy: 0.9933 - val_loss: 0.0826 - val_accuracy: 0.9607
# Epoch 25/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0870 - accuracy: 0.9933 - val_loss: 0.0813 - val_accuracy: 0.9607
# Epoch 26/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0866 - accuracy: 0.9933 - val_loss: 0.0896 - val_accuracy: 0.9607
# Epoch 27/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0868 - accuracy: 0.9933 - val_loss: 0.0807 - val_accuracy: 0.9607
# Epoch 28/100
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0871 - accuracy: 0.9933 - val_loss: 0.0824 - val_accuracy: 0.9607
# Epoch 29/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0871 - accuracy: 0.9933 - val_loss: 0.0803 - val_accuracy: 0.9607
# Epoch 30/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0869 - accuracy: 0.9933 - val_loss: 0.0814 - val_accuracy: 0.9607
# Epoch 31/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0872 - accuracy: 0.9933 - val_loss: 0.0827 - val_accuracy: 0.9607
# Epoch 32/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0866 - accuracy: 0.9933 - val_loss: 0.0819 - val_accuracy: 0.9607
# Epoch 33/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0864 - accuracy: 0.9933 - val_loss: 0.0854 - val_accuracy: 0.9607
# Epoch 34/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0874 - accuracy: 0.9933 - val_loss: 0.0811 - val_accuracy: 0.9607
# Epoch 35/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0866 - accuracy: 0.9933 - val_loss: 0.0819 - val_accuracy: 0.9607
# Epoch 36/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0868 - accuracy: 0.9933 - val_loss: 0.0863 - val_accuracy: 0.9607
# Epoch 37/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0862 - accuracy: 0.9933 - val_loss: 0.0812 - val_accuracy: 0.9607
# Epoch 38/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0865 - accuracy: 0.9933 - val_loss: 0.0810 - val_accuracy: 0.9607
# Epoch 39/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0862 - accuracy: 0.9933 - val_loss: 0.0804 - val_accuracy: 0.9607
# Epoch 40/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0861 - accuracy: 0.9933 - val_loss: 0.0801 - val_accuracy: 0.9607
# Epoch 41/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0861 - accuracy: 0.9933 - val_loss: 0.0810 - val_accuracy: 0.9607
# Epoch 42/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0860 - accuracy: 0.9933 - val_loss: 0.0818 - val_accuracy: 0.9607
# Epoch 43/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0865 - accuracy: 0.9933 - val_loss: 0.0815 - val_accuracy: 0.9607
# Epoch 44/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0863 - accuracy: 0.9933 - val_loss: 0.0820 - val_accuracy: 0.9607
# Epoch 45/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0866 - accuracy: 0.9933 - val_loss: 0.0808 - val_accuracy: 0.9607
# Epoch 46/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0868 - accuracy: 0.9933 - val_loss: 0.0810 - val_accuracy: 0.9607
# Epoch 47/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0860 - accuracy: 0.9933 - val_loss: 0.0839 - val_accuracy: 0.9607
# Epoch 48/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0861 - accuracy: 0.9933 - val_loss: 0.0803 - val_accuracy: 0.9607
# Epoch 49/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0859 - accuracy: 0.9933 - val_loss: 0.0798 - val_accuracy: 0.9607
# Epoch 50/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0860 - accuracy: 0.9933 - val_loss: 0.0811 - val_accuracy: 0.9607
# Epoch 51/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0861 - accuracy: 0.9933 - val_loss: 0.0807 - val_accuracy: 0.9607
# Epoch 52/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0858 - accuracy: 0.9933 - val_loss: 0.0792 - val_accuracy: 0.9607
# Epoch 53/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0856 - accuracy: 0.9933 - val_loss: 0.0815 - val_accuracy: 0.9607
# Epoch 54/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0862 - accuracy: 0.9933 - val_loss: 0.0815 - val_accuracy: 0.9607
# Epoch 55/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0859 - accuracy: 0.9933 - val_loss: 0.0806 - val_accuracy: 0.9607
# Epoch 56/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0857 - accuracy: 0.9933 - val_loss: 0.0803 - val_accuracy: 0.9607
# Epoch 57/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0859 - accuracy: 0.9933 - val_loss: 0.0798 - val_accuracy: 0.9607
# Epoch 58/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0862 - accuracy: 0.9933 - val_loss: 0.0819 - val_accuracy: 0.9607
# Epoch 59/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0860 - accuracy: 0.9933 - val_loss: 0.0799 - val_accuracy: 0.9607
# Epoch 60/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0858 - accuracy: 0.9933 - val_loss: 0.0808 - val_accuracy: 0.9607
# Epoch 61/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0858 - accuracy: 0.9933 - val_loss: 0.0801 - val_accuracy: 0.9607
# Epoch 62/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0856 - accuracy: 0.9933 - val_loss: 0.0800 - val_accuracy: 0.9607
# Epoch 63/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0858 - accuracy: 0.9933 - val_loss: 0.0831 - val_accuracy: 0.9607
# Epoch 64/100
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0856 - accuracy: 0.9933 - val_loss: 0.0804 - val_accuracy: 0.9607
# Epoch 65/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0857 - accuracy: 0.9933 - val_loss: 0.0797 - val_accuracy: 0.9607
# Epoch 66/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0856 - accuracy: 0.9933 - val_loss: 0.0813 - val_accuracy: 0.9607
# Epoch 67/100
# 72/72 [==============================] - 1s 20ms/step - loss: 0.0855 - accuracy: 0.9933 - val_loss: 0.0804 - val_accuracy: 0.9607
# Epoch 68/100
# 72/72 [==============================] - 1s 20ms/step - loss: 0.0855 - accuracy: 0.9933 - val_loss: 0.0800 - val_accuracy: 0.9607
# Epoch 69/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0856 - accuracy: 0.9933 - val_loss: 0.0815 - val_accuracy: 0.9607
# Epoch 70/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0857 - accuracy: 0.9933 - val_loss: 0.0794 - val_accuracy: 0.9607
# Epoch 71/100
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0855 - accuracy: 0.9933 - val_loss: 0.0798 - val_accuracy: 0.9607
# Epoch 72/100
# 72/72 [==============================] - 1s 20ms/step - loss: 0.0855 - accuracy: 0.9933 - val_loss: 0.0812 - val_accuracy: 0.9607
# Epoch 73/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0851 - accuracy: 0.9933 - val_loss: 0.0801 - val_accuracy: 0.9607
# Epoch 74/100
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0854 - accuracy: 0.9933 - val_loss: 0.0811 - val_accuracy: 0.9607
# Epoch 75/100
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0853 - accuracy: 0.9933 - val_loss: 0.0799 - val_accuracy: 0.9607
# Epoch 76/100
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0853 - accuracy: 0.9933 - val_loss: 0.0797 - val_accuracy: 0.9607
# Epoch 77/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0856 - accuracy: 0.9933 - val_loss: 0.0799 - val_accuracy: 0.9607
# Epoch 78/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0854 - accuracy: 0.9933 - val_loss: 0.0808 - val_accuracy: 0.9607
# Epoch 79/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0855 - accuracy: 0.9933 - val_loss: 0.0819 - val_accuracy: 0.9607
# Epoch 80/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0852 - accuracy: 0.9933 - val_loss: 0.0815 - val_accuracy: 0.9607
# Epoch 81/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0850 - accuracy: 0.9933 - val_loss: 0.0809 - val_accuracy: 0.9607
# Epoch 82/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0853 - accuracy: 0.9933 - val_loss: 0.0803 - val_accuracy: 0.9607
# Epoch 83/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0848 - accuracy: 0.9933 - val_loss: 0.0810 - val_accuracy: 0.9607
# Epoch 84/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0855 - accuracy: 0.9933 - val_loss: 0.0807 - val_accuracy: 0.9607
# Epoch 85/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0851 - accuracy: 0.9933 - val_loss: 0.0801 - val_accuracy: 0.9607
# Epoch 86/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0855 - accuracy: 0.9933 - val_loss: 0.0817 - val_accuracy: 0.9607
# Epoch 87/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0849 - accuracy: 0.9933 - val_loss: 0.0810 - val_accuracy: 0.9607
# Epoch 88/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0848 - accuracy: 0.9933 - val_loss: 0.0804 - val_accuracy: 0.9607
# Epoch 89/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0847 - accuracy: 0.9933 - val_loss: 0.0815 - val_accuracy: 0.9607
# Epoch 90/100
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0852 - accuracy: 0.9933 - val_loss: 0.0814 - val_accuracy: 0.9607
# Epoch 91/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0849 - accuracy: 0.9933 - val_loss: 0.0801 - val_accuracy: 0.9607
# Epoch 92/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0847 - accuracy: 0.9933 - val_loss: 0.0807 - val_accuracy: 0.9607
# Epoch 93/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0848 - accuracy: 0.9933 - val_loss: 0.0811 - val_accuracy: 0.9607
# Epoch 94/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0849 - accuracy: 0.9933 - val_loss: 0.0811 - val_accuracy: 0.9607
# Epoch 95/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0846 - accuracy: 0.9933 - val_loss: 0.0799 - val_accuracy: 0.9607
# Epoch 96/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0849 - accuracy: 0.9933 - val_loss: 0.0807 - val_accuracy: 0.9607
# Epoch 97/100
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0844 - accuracy: 0.9933 - val_loss: 0.0805 - val_accuracy: 0.9607
# Epoch 98/100
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0846 - accuracy: 0.9933 - val_loss: 0.0805 - val_accuracy: 0.9607
# Epoch 99/100
# 72/72 [==============================] - 1s 14ms/step - loss: 0.0847 - accuracy: 0.9933 - val_loss: 0.0799 - val_accuracy: 0.9607
# Epoch 100/100
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0847 - accuracy: 0.9933 - val_loss: 0.0816 - val_accuracy: 0.9607
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0852 - accuracy: 0.9933
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0816 - accuracy: 0.9607

# %% [markdown]
# - The model results were very strange. It seems that the model is overfitting the trianing data. Also it is strange that the validation accuracy is constant.
# - We may try simplifying the model

# %% [markdown]
# ### 5.3.2. <a id='toc5_3_2_'></a>[second run](#toc0_)

# %%
model= Seq2SeqPredictor(Encoder=LSTMEncoder,Decoder=LSTMDecoder,steps=steps,
                        num_features=fratures,num_layers=1,num_units=[30])

compile_kwargs = { 'loss': keras.losses.MeanAbsoluteError () ,
                    'optimizer':keras.optimizers.Adam(learning_rate=0.001),
                    'metrics':['accuracy']}
                    
fit_kwargs = {'x': x_train, 'y' :y_train , 'validation_data' : (x_val,y_val),
               'epochs':25, 'batch_size' : 12,'shuffle':True}
model.train_model(compile_kwargs, fit_kwargs,expirement_name= 'Seq2seq-LSTM',run_name= '1layers-30units')
# Out:
# Epoch 1/25
# 72/72 [==============================] - 4s 30ms/step - loss: 0.1853 - accuracy: 0.6274 - val_loss: 0.1044 - val_accuracy: 0.9607
# Epoch 2/25
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1017 - accuracy: 0.9933 - val_loss: 0.0958 - val_accuracy: 0.9607
# Epoch 3/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0964 - accuracy: 0.9933 - val_loss: 0.0915 - val_accuracy: 0.9607
# Epoch 4/25
# 72/72 [==============================] - 2s 23ms/step - loss: 0.0930 - accuracy: 0.9933 - val_loss: 0.0894 - val_accuracy: 0.9607
# Epoch 5/25
# 72/72 [==============================] - 2s 22ms/step - loss: 0.0911 - accuracy: 0.9933 - val_loss: 0.0857 - val_accuracy: 0.9607
# Epoch 6/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0903 - accuracy: 0.9933 - val_loss: 0.0877 - val_accuracy: 0.9607
# Epoch 7/25
# 72/72 [==============================] - 1s 21ms/step - loss: 0.0903 - accuracy: 0.9933 - val_loss: 0.0854 - val_accuracy: 0.9607
# Epoch 8/25
# 72/72 [==============================] - 1s 14ms/step - loss: 0.0894 - accuracy: 0.9933 - val_loss: 0.0836 - val_accuracy: 0.9607
# Epoch 9/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0893 - accuracy: 0.9933 - val_loss: 0.0838 - val_accuracy: 0.9607
# Epoch 10/25
# 72/72 [==============================] - 1s 14ms/step - loss: 0.0890 - accuracy: 0.9933 - val_loss: 0.0833 - val_accuracy: 0.9607
# Epoch 11/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0890 - accuracy: 0.9933 - val_loss: 0.0852 - val_accuracy: 0.9607
# Epoch 12/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0888 - accuracy: 0.9933 - val_loss: 0.0830 - val_accuracy: 0.9607
# Epoch 13/25
# 72/72 [==============================] - 1s 20ms/step - loss: 0.0883 - accuracy: 0.9933 - val_loss: 0.0851 - val_accuracy: 0.9607
# Epoch 14/25
# 72/72 [==============================] - 2s 27ms/step - loss: 0.0882 - accuracy: 0.9933 - val_loss: 0.0824 - val_accuracy: 0.9607
# Epoch 15/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0884 - accuracy: 0.9933 - val_loss: 0.0821 - val_accuracy: 0.9607
# Epoch 16/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0881 - accuracy: 0.9933 - val_loss: 0.0841 - val_accuracy: 0.9607
# Epoch 17/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0879 - accuracy: 0.9933 - val_loss: 0.0845 - val_accuracy: 0.9607
# Epoch 18/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0881 - accuracy: 0.9933 - val_loss: 0.0826 - val_accuracy: 0.9607
# Epoch 19/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0876 - accuracy: 0.9933 - val_loss: 0.0840 - val_accuracy: 0.9607
# Epoch 20/25
# 72/72 [==============================] - 2s 23ms/step - loss: 0.0876 - accuracy: 0.9933 - val_loss: 0.0853 - val_accuracy: 0.9607
# Epoch 21/25
# 72/72 [==============================] - 2s 27ms/step - loss: 0.0874 - accuracy: 0.9933 - val_loss: 0.0850 - val_accuracy: 0.9607
# Epoch 22/25
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0874 - accuracy: 0.9933 - val_loss: 0.0844 - val_accuracy: 0.9607
# Epoch 23/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0872 - accuracy: 0.9933 - val_loss: 0.0830 - val_accuracy: 0.9607
# Epoch 24/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0874 - accuracy: 0.9933 - val_loss: 0.0839 - val_accuracy: 0.9607
# Epoch 25/25
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0874 - accuracy: 0.9933 - val_loss: 0.0818 - val_accuracy: 0.9607
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0871 - accuracy: 0.9933
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0818 - accuracy: 0.9607

# %% [markdown]
# - Yet the loss curves doen't show overfitting, but the accuracy curves do.
# - Since the validation accuracy is constant while the validation loss is monotonically decreasing, this may mean the model is doing very well on some validation samples, and very bad on others.
# - We may try to change the learning rate to overcome this.

# %% [markdown]
# ### 5.3.3. <a id='toc5_3_3_'></a>[Third run](#toc0_)

# %%
model= Seq2SeqPredictor(Encoder=LSTMEncoder,Decoder=LSTMDecoder,steps=steps,
                        num_features=fratures,num_layers=1,num_units=[10])

compile_kwargs = { 'loss': keras.losses.MeanAbsoluteError () ,
                    'optimizer':keras.optimizers.Adam(learning_rate=0.0001),
                    'metrics':['accuracy']}
                    
fit_kwargs = {'x': x_train, 'y' :y_train , 'validation_data' : (x_val,y_val),
               'epochs':25, 'batch_size' : 12,'shuffle':True}
model.train_model(compile_kwargs, fit_kwargs,expirement_name= 'Seq2seq-LSTM',run_name= '1layer-10units-lrdecreased')
# Out:
# Epoch 1/25
# 72/72 [==============================] - 5s 47ms/step - loss: 0.3888 - accuracy: 0.0055 - val_loss: 0.3781 - val_accuracy: 0.0189
# Epoch 2/25
# 72/72 [==============================] - 2s 23ms/step - loss: 0.3605 - accuracy: 0.0012 - val_loss: 0.3485 - val_accuracy: 0.0204
# Epoch 3/25
# 72/72 [==============================] - 4s 51ms/step - loss: 0.3310 - accuracy: 0.0012 - val_loss: 0.3176 - val_accuracy: 0.0214
# Epoch 4/25
# 72/72 [==============================] - 4s 49ms/step - loss: 0.2972 - accuracy: 0.0012 - val_loss: 0.2776 - val_accuracy: 0.0214
# Epoch 5/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.2531 - accuracy: 0.0012 - val_loss: 0.2278 - val_accuracy: 0.0214
# Epoch 6/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.2098 - accuracy: 0.0013 - val_loss: 0.1937 - val_accuracy: 0.0214
# Epoch 7/25
# 72/72 [==============================] - 3s 35ms/step - loss: 0.1834 - accuracy: 0.0782 - val_loss: 0.1696 - val_accuracy: 0.1173
# Epoch 8/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.1596 - accuracy: 0.8585 - val_loss: 0.1439 - val_accuracy: 0.9582
# Epoch 9/25
# 72/72 [==============================] - 3s 42ms/step - loss: 0.1331 - accuracy: 0.9933 - val_loss: 0.1183 - val_accuracy: 0.9607
# Epoch 10/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.1164 - accuracy: 0.9933 - val_loss: 0.1094 - val_accuracy: 0.9607
# Epoch 11/25
# 72/72 [==============================] - 3s 42ms/step - loss: 0.1103 - accuracy: 0.9933 - val_loss: 0.1057 - val_accuracy: 0.9607
# Epoch 12/25
# 72/72 [==============================] - 2s 26ms/step - loss: 0.1075 - accuracy: 0.9933 - val_loss: 0.1033 - val_accuracy: 0.9607
# Epoch 13/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.1058 - accuracy: 0.9933 - val_loss: 0.1015 - val_accuracy: 0.9607
# Epoch 14/25
# 72/72 [==============================] - 3s 34ms/step - loss: 0.1044 - accuracy: 0.9933 - val_loss: 0.1005 - val_accuracy: 0.9607
# Epoch 15/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.1033 - accuracy: 0.9933 - val_loss: 0.0994 - val_accuracy: 0.9607
# Epoch 16/25
# 72/72 [==============================] - 2s 24ms/step - loss: 0.1024 - accuracy: 0.9933 - val_loss: 0.0985 - val_accuracy: 0.9607
# Epoch 17/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.1015 - accuracy: 0.9933 - val_loss: 0.0975 - val_accuracy: 0.9607
# Epoch 18/25
# 72/72 [==============================] - 2s 27ms/step - loss: 0.1007 - accuracy: 0.9933 - val_loss: 0.0968 - val_accuracy: 0.9607
# Epoch 19/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.1000 - accuracy: 0.9933 - val_loss: 0.0960 - val_accuracy: 0.9607
# Epoch 20/25
# 72/72 [==============================] - 2s 25ms/step - loss: 0.0993 - accuracy: 0.9933 - val_loss: 0.0950 - val_accuracy: 0.9607
# Epoch 21/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0986 - accuracy: 0.9933 - val_loss: 0.0942 - val_accuracy: 0.9607
# Epoch 22/25
# 72/72 [==============================] - 2s 33ms/step - loss: 0.0979 - accuracy: 0.9933 - val_loss: 0.0938 - val_accuracy: 0.9607
# Epoch 23/25
# 72/72 [==============================] - 1s 15ms/step - loss: 0.0973 - accuracy: 0.9933 - val_loss: 0.0932 - val_accuracy: 0.9607
# Epoch 24/25
# 72/72 [==============================] - 2s 25ms/step - loss: 0.0968 - accuracy: 0.9933 - val_loss: 0.0927 - val_accuracy: 0.9607
# Epoch 25/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0964 - accuracy: 0.9933 - val_loss: 0.0923 - val_accuracy: 0.9607
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0961 - accuracy: 0.9933
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0923 - accuracy: 0.9607

# %%
model.save(localpath.models.value/'seq2seq_lstm.keras')

# %% [markdown]
# # 6. <a id='toc6_'></a>[Evaluation](#toc0_)

# %%
def predict(scaler,model,input):
    scaled= model.predict(input)
    unscaled= scaler.inverse_transform(scaled)
    return unscaled

# %%
model.evaluate(x_test,y_test)
# Out:
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0947 - accuracy: 0.9786
# [0.09469623118638992, 0.9785714149475098]

# %% [markdown]
# - It's also important to plot each variable predictions. But due to the tight timeframe, this will be ignored.

# %% [markdown]
# # 7. <a id='toc7_'></a>[Deployment](#toc0_)

# %% [markdown]
# **Deployment Strategies**<br>
#
# There are several ways to deploy the model, each with its strengths:
#
# - **Stand-alone Application:** To develop a user-friendly application (using tools like Flask) that loads the trained model. Users can input historical data and receive predicted future consumption. This is a good option for initial testing and exploration by the energy company.
# - **Cloud based:** Cloud platforms like Google Cloud AI Platform, Amazon SageMaker, or Microsoft Azure Machine Learning offer exciting possibilities:
#     - Scalability: Handle surges in prediction requests without issues.
#     - Real-time Predictions: Integrate seamlessly with live data streams for on-the-fly forecasting.
#     - API Access: Allow external applications to interact with the model using an API, opening up possibilities for wider integration.
#     - Embedded Device Potential: Explore deploying a lightweight version of the model on an embedded device for scenarios where on-site predictions are needed (e.g., smart meters).

# %%
#create app
app = Flask(__name__)
# Load the model
model= keras.saving.load_model(localpath.models.value/'seq2seq_lstm.keras')
#load the preprocessor
file = open(localpath.models.value/'scaler.pickle', 'rb')
data = pickle.load(file)
@app.route('/api',methods=['POST'])
def predict():
    # Get the data from the POST request.
    data = request.get_json(force=True)
    # Make prediction using model loaded from disk as per the data.
    prediction = model.predict(np.array(data))
    prediction= scaler.inverse_transform(prediction)
    # Take the first value of prediction
    output = prediction
    return jsonify(output)
if __name__ == '__main__':
    app.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/May/2024 23:56:23] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [06/May/2024 23:56:24] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/May/2024 23:56:30] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [06/May/2024 23:56:36] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [06/May/2024 23:57:48] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [06/May/2024 23:58:04] "GET /api HTTP/1.1" 405 -
